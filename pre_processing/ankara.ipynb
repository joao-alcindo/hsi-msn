# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
# read .bmp and .mat files
from scipy.io import loadmat
from PIL import Image
import glob
import time
import random
import warnings
warnings.filterwarnings("ignore")

# %%
files_path = './../../../AnkaraHSIARCHIVE/'
bmp_files = glob.glob(os.path.join(files_path, '*.bmp'))
